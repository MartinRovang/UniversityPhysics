# %%
# import codecs
# file_data = codecs.open('data.dat','r', 'utf-8')

# table = []
# import csv

# for row in csv.reader(file_data):
#     print(row)
#     table.append(row)


# file_data.close()

# print(table[1:][0])

# table2 = [float(i) for i in table[1:]]

import numpy as np


file_data = np.loadtxt('data.dat', skiprows = 1)

data_1 = file_data[0]
data_2 = file_data[1]


print(data_1)

import matplotlib.pyplot as plt


plt.plot(data_1)
plt.show()
# Out:
# [  1.07  12.    12.5   13.6 ]

# %%
dataframe = {
    "Cars":[1,2,3,4,5,6],
    "Larvas":[5,2,5,2,4,1]
}

import matplotlib.pyplot as plt

plt.plot(dataframe["Cars"], dataframe["Larvas"])
plt.show()

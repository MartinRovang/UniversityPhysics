# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
sns.set(color_codes=True)
#mydata1  = pd.read_csv("C:\\test.csv", header = None)
#print(mydata1)

y1 = np.array([68.3, 67.6, 67.7, 67.4, 68.6, 68.3, 68.2, 69.8])
x1 = np.array([1, 2, 3, 4, 5, 6, 7, 8])


g = sns.regplot(x=x1,y=y1 ,ci = 50, color = "r");
plt.show()

y2 = np.array([[68.3], [67.6], [67.7], [67.4], [68.6], [68.3], [68.2], [69.8]])
x2 = np.array([[1], [2], [3], [4], [5], [6], [7], [8]])

model = LinearRegression()
model.fit(x2,y2)
model.coef_ #økning per x
# Out:
# array([[ 0.19642857]])
